# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup as bs

with open('response_Jan_24.html', 'r', encoding='utf-8') as f:
    soup = bs(f, 'html.parser')



print(soup.find('table',{'id':'monthResults'}))
# Out:
# None

# %%
t1 = pd.read_html(r'C:\Users\Surenjanath Singh\Downloads\Lotto_Automated_Webscraper-main(1)\Lotto_Automated_Webscraper-main\response_Jan_24.html')[0]

# %%
t1
# Out:
#                                                 Draw#  \
# 0                                           01-Jan-24
# 1                                                7047
# 2                                           02-Jan-24
# 3                                                7048
# 4                                           03-Jan-24
# 5                                                7049
# 6                                           04-Jan-24
# 7                                                7050
# 8                                           05-Jan-24
# 9                                                7051
# 10                                          06-Jan-24
# 11                                               7052
# 12                                          08-Jan-24
# 13                                               7053
# 14                                          09-Jan-24
# 15                                               7054
# ...
